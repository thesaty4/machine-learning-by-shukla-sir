# %%
class mylist:
    l=[]

    def __init__(s,n):
        temp=[]
        for i in range(n):
            x=int(input("Enter the data of the list:"))
            temp.append(x)
        s.l=temp
        
    def display(s):
        print(s.l)
        
    def min(s):
        min=s.l[0]
        for i in s.l:
            if(i<min):
                min=i
        return min

    def max(s):
        max=s.l[0]
        for i in s.l:
            if(i>max):
                max=i
        return max

    def interchange(s):
        temp=s.l[0]
        s.l[0]=s.l[-1] #-1 index means last element
        s.l[-1]=temp
        return s.l

    def average(s):
        sum=0
        count=0
        for i in s.l:
            sum=sum+i
            count=count+1
        mean=sum/count
        return mean

    def count(s):
        count=0
        for i in s.l:
            count=count+1
        return count

    def sum(s):
        sum=0
        for i in s.l:
            sum=sum+i
        return sum

class mynumber:
    number=0
    
    def __init__(s,n):
        s.number=n
    
    def iseven(s):
        if(s.number%2==0):
            return 1
        else:
            return 0
    
    def factorial(s):
        fact=1
        for i in range(1,s.number+1):
            fact=fact*i
        return fact

    def isprime(s):
        for i in range(2,int(s.number/2)):
            if(s.number%i==0):
                return False
                #print("It is not a Prime Number")
                break 
        else: 
            return True
        
def multi(a,b):
    c=a*b
    return c

pi=3.14

#A module can contain any thing for ex: class, function,or any data: list, dictionary,tuple, set, or just a single variable
