# %%
import pandas as pd
df=pd.read_csv("Day16_1.csv")
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.234413  0.272245  0.310360  0.328018  0.329967  0.325480  0.320175
# 1  0.246744  0.273927  0.303082  0.321856  0.333889  0.333324  0.324096
# 2  0.262430  0.281770  0.303082  0.321856  0.345654  0.345088  0.324096
# 3  0.262430  0.289613  0.306170  0.325778  0.351547  0.345088  0.320175
# 4  0.242554  0.287396  0.314013  0.329700  0.355469  0.343704  0.314587
#
#           7         8         9  ...       122       123       124       125  \
# 0  0.310680  0.317139  0.308731  ...  0.318991  0.313395  0.274462  0.309474
# 1  0.306758  0.322200  0.312652  ...  0.311148  0.313395  0.274462  0.305552
# 2  0.302837  0.322200  0.312652  ...  0.307227  0.321238  0.286227  0.309474
# 3  0.298915  0.314356  0.312652  ...  0.303305  0.329082  0.294070  0.313395
# 4  0.306758  0.314356  0.316574  ...  0.295462  0.325160  0.297992  0.309474
#
#         126       127       128       129       130     131
# ...

# %%
from skimage.io import imshow
import matplotlib.pyplot as plt
plt.imshow(df)
plt.show()

# %%
df.shape
# Out:
# (133, 132)

# %%
#Reading an Image file in Python
from skimage.io import imshow,imread
df=imread("D:\\BBAU1\\Image Classification\\6.jpg")
df.shape
# Out:
# (4032, 2268, 3)

# %%
#4032 is number of pixels (length)
#width: 2268 pixels
# 3 is color value(RGB)

# %%
print(df[1000][1000])
# Out:
# [152 162 154]

# %%
#R=152
#G=162
#B=154
#RGB is between 0 to 255
print(df[1001][1000])
# Out:
# [156 163 156]

# %%
imshow(df)

# %%
df=imread("D:\\BBAU1\\Image Classification\\6.jpg",as_gray=True)
df.shape
# Out:
# (4032, 2268)

# %%
print(df[1000][1000])
# Out:
# 0.6246988235294118

# %%
imshow(df)
