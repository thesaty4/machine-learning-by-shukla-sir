# %%
import pickle

pkl_filename = "pickle_model.pkl"

# Load from file
with open(pkl_filename, 'rb') as file:
    (model,X_train) = pickle.load(file)

# %%
#JSON- Java Standard Object Notation
#pip install json
import json

person = '{"name": "Ravi", "languages": ["English", "French"]}'
person_dict = json.loads(person)
print(person_dict['languages'])
# Out:
# ['English', 'French']

# %%
import json

with open('student.json') as f:
    data = json.load(f)
print(data)
print(data['name'])
# Out:
# {'name': 'Ravi', 'languages': ['English', 'French']}
# Ravi

# %%
import json

student = {'name': 'Ravi',
'age': 12,
'children': None
}
student_json = json.dumps(student)


print(student_json)
# Out:
# {"name": "Ravi", "age": 12, "children": null}

# %%
with open('24_Aug_25.txt', 'w') as json_file:
    json.dump(student_json, json_file)

# %%
import requests
response = requests.get("https://jsonplaceholder.typicode.com/todos")
todos = json.loads(response.text)

# %%
print(todos)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}, {'userId': 1, 'id': 2, 'title': 'quis ut nam facilis et officia qui', 'completed': False}, {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False}, {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True}, {'userId': 1, 'id': 5, 'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum', 'completed': False}, {'userId': 1, 'id': 6, 'title': 'qui ullam ratione quibusdam voluptatem quia omnis', 'completed': False}, {'userId': 1, 'id': 7, 'title': 'illo expedita consequatur quia in', 'completed': False}, {'userId': 1, 'id': 8, 'title': 'quo adipisci enim quam ut ab', 'completed': True}, {'userId': 1, 'id': 9, 'title': 'molestiae perspiciatis ipsa', 'completed': False}, {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True}, {'userId': 1, 'id': 11, 'title': 'vero rerum temporibus dolor', 'completed': True}, {'userId': 1, 
# ...

# %%
#beautification of JSON format data
#def jprint(obj):
    # create a formatted string of the Python JSON object
text = json.dumps(todos, sort_keys=True, indent=4)
print(text)

#jprint(todos)
# Out:
# [
#     {
#         "completed": false,
#         "id": 1,
#         "title": "delectus aut autem",
#         "userId": 1
#     },
#     {
#         "completed": false,
#         "id": 2,
#         "title": "quis ut nam facilis et officia qui",
#         "userId": 1
#     },
#     {
#         "completed": false,
#         "id": 3,
#         "title": "fugiat veniam minus",
#         "userId": 1
#     },
#     {
#         "completed": true,
#         "id": 4,
#         "title": "et porro tempora",
#         "userId": 1
#     },
#     {
#         "completed": false,
#         "id": 5,
#         "title": "laboriosam mollitia et enim quasi adipisci quia provident illum",
#         "userId": 1
#     },
#     {
#         "completed": false,
#         "id": 6,
#         "title": "qui ullam ratione quibusdam voluptatem quia omnis",
#         "userId": 1
#     },
#     {
#         "completed": false,
#         "id": 7,
#         "title": "illo expedita consequatur quia in",
# ...

# %%
print(todos[0])
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
print(todos[0]['title'])
# Out:
# delectus aut autem

# %%
a=todos[0]
print(a)
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
type(a)
# Out:
# dict

# %%
import pandas as pd
titles=[]
for i in todos:
    a=i['title']
    b=i['userId']
    c=i['completed']
    d=[a,b,c]
    titles.append(d)
df=pd.DataFrame(titles,columns=["Title",'userId','Status'])

# %%
df.head()
# Out:
#                                                Title  userId  Status
# 0                                 delectus aut autem       1   False
# 1                 quis ut nam facilis et officia qui       1   False
# 2                                fugiat veniam minus       1   False
# 3                                   et porro tempora       1    True
# 4  laboriosam mollitia et enim quasi adipisci qui...       1   False

# %%
df['Status'].value_counts()
# Out:
# False    110
# True      90
# Name: Status, dtype: int64
